# %% [markdown]
# ### DeGirum PySDK Tutorial for Hailo8L/HAILO8
# In this notebook, we illustrate the main features of PySDK and how it can be used to quickly develop edge AI applications using the `Hailo8L/HAILO8` accelerator. See [Setup Instructions for PySDK Notebooks](../README.md#setup-instructions-for-pysdk-notebooks).
#
# DeGirum's PySDK provides simple APIs to run AI model inference. In general, there are three steps in running an AI model:
# 1. Loading model using `degirum.load_model` method
# 2. Running inference on an input using the `model.predict` method
# 3. Visualizing inference results using the `results.image_overlay` method

# %%
# import degirum and degirum_tools
import degirum as dg, degirum_tools

inference_host_address = "@local"
zoo_url = 'degirum/hailo'
token=''
device_type='HAILORT/HAILO8'

# set model name, and image source
model_name = "yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1"
image_source='../assets/ThreePersons.jpg'

# load AI model
model = dg.load_model(
    model_name=model_name,
    inference_host_address=inference_host_address,
    zoo_url=zoo_url,
    token=token,
    device_type=device_type,    
)

# perform AI model inference on given image source
print(f" Running inference using '{model_name}' on image source '{image_source}'")
inference_result = model(image_source)

# print('Inference Results \n', inference_result)  # numeric results
print(inference_result)
print("Press 'x' or 'q' to stop.")

# show results of inference
with degirum_tools.Display("AI Camera") as output_display:
    output_display.show_image(inference_result.image_overlay)
# Out:
# ---------------------------------------------------------------------------
# DegirumException                          Traceback (most recent call last)
# Cell In[1], line 14
#      11 image_source='../assets/ThreePersons.jpg'
#      13 # load AI model
# ---> 14 model = dg.load_model(
#      15     model_name=model_name,
#      16     inference_host_address=inference_host_address,
#      17     zoo_url=zoo_url,
#      18     token=token,
#      19     device_type=device_type,
#      20 )
#      22 # perform AI model inference on given image source
#      23 print(f" Running inference using '{model_name}' on image source '{image_source}'")
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/__init__.py:222, in load_model(model_name, inference_host_address, zoo_url, token, **kwargs)
#     198 """
#     199 Load a model from the model zoo for the inference.
#     200
#    (...)    219     An instance of [degirum.model.Model][] model handling object to be used for AI inferences.
#     220 """
#     221 zoo = ZooManager(inference_host_address, zoo_url, token)
# --> 222 return zoo.load_model(model_name, **kwargs)
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/log.py:84, in log_wrap.<locals>.wrap(*args, **kwargs)
#      82 try:
#      83     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 84     return f(*args, **kwargs)
#      85 finally:
#      86     t2 = time.time_ns()
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/zoo_manager.py:319, in ZooManager.load_model(self, model_name, **kwargs)
#     257 @log_wrap
#     258 def load_model(self, model_name: str, **kwargs) -> Model:
#     259     """Create and return the model handling object for given model name.
#     260
#     261     Args:
#    (...)    317
#     318     """
# --> 319     model = self._zoo.load_model(model_name)
#     320     for key, value in kwargs.items():
#     321         if hasattr(Model, key):
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/log.py:84, in log_wrap.<locals>.wrap(*args, **kwargs)
#      82 try:
#      83     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 84     return f(*args, **kwargs)
#      85 finally:
#      86     t2 = time.time_ns()
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/_zoo_accessor.py:632, in _LocalHWCloudZooAccessor.load_model(self, model)
#     621 @log_wrap
#     622 def load_model(self, model: str):
#     623     """Create model object for given model name.
#     624
#     625     Args:
#    (...)    629         model object corresponding to given model name
#     630     """
# --> 632     assets = self._get_model_assets(model, True)
#     633     model_params: ModelParams = copy.deepcopy(assets.model_params)
#     634     model_params.CloudModelName = self.ext_model_name(model)
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/_zoo_accessor.py:583, in _CloudZooAccessorBase._get_model_assets(self, model, get_labels)
#     580 assets = self._assets.get(model)
#     582 if assets is None or assets.model_params is None:
# --> 583     model_info = self._cloud_server_request(
#     584         f"/zoo/v1/public/models{self._zoo_url}/{model}/info"
#     585     )
#     587     assets = self._Assets(
#     588         ModelParams(json.dumps(model_info["model_params"])),
#     589         Model._harmonize_label_dictionary(model_info["model_labels"]),
#     590     )
#     591     self._assets[model] = assets
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/log.py:84, in log_wrap.<locals>.wrap(*args, **kwargs)
#      82 try:
#      83     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 84     return f(*args, **kwargs)
#      85 finally:
#      86     t2 = time.time_ns()
#
# File ~/ai_digital_signage/ai_digital_signage_env/lib/python3.11/site-packages/degirum/_zoo_accessor.py:501, in _CloudZooAccessorBase._cloud_server_request(self, api_url, is_octet_stream)
#     499     except json.JSONDecodeError:
#     500         pass
# --> 501     raise DegirumException(details) from None
#     503 # if we followed a redirect to https, update url
#     504 if (
#     505     len(res.history) == 1
#     506     and res.url.startswith("https://")
#     507     and self._url.startswith("http://")
#     508 ):
#
# DegirumException: could not get model by url. (cloud server response: 400 Client Error: Bad Request for url: https://hub.degirum.com/zoo/v1/public/models/degirum/hailo/yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1/info)

# %% [markdown]
# #### Running Inference on Video Stream
# - The `predict_stream` function in `degirum_tools` provides a powerful and efficient way to perform AI inference on video streams in real-time. It processes video frames sequentially and returns inference results frame by frame, enabling seamless integration with various video input sources.
# - The code below shows how to use `predict_stream` on a video file.

# %%
import degirum as dg, degirum_tools

inference_host_address = "@local"
zoo_url = 'degirum/hailo'
token=''
device_type='HAILORT/HAILO8'

model_name = "yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1"
video_source = '../assets/Traffic.mp4'

# load AI model
model = dg.load_model(
    model_name=model_name,
    inference_host_address=inference_host_address,
    zoo_url=zoo_url,
    token=token,
    device_type=device_type
)

with degirum_tools.Display("AI Camera") as output_display:
    for inference_result in degirum_tools.predict_stream(model, video_source):
        output_display.show(inference_result)
# Out:
# ---------------------------------------------------------------------------
# DegirumException                          Traceback (most recent call last)
# Cell In[1], line 12
#       9 video_source = '../assets/Traffic.mp4'
#      11 # load AI model
# ---> 12 model = dg.load_model(
#      13     model_name=model_name,
#      14     inference_host_address=inference_host_address,
#      15     zoo_url=zoo_url,
#      16     token=token,
#      17     device_type=device_type
#      18 )
#      20 with degirum_tools.Display("AI Camera") as output_display:
#      21     for inference_result in degirum_tools.predict_stream(model, video_source):
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/__init__.py:222, in load_model(model_name, inference_host_address, zoo_url, token, **kwargs)
#     198 """
#     199 Load a model from the model zoo for the inference.
#     200
#    (...)    219     An instance of [degirum.model.Model][] model handling object to be used for AI inferences.
#     220 """
#     221 zoo = ZooManager(inference_host_address, zoo_url, token)
# --> 222 return zoo.load_model(model_name, **kwargs)
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/log.py:84, in log_wrap.<locals>.wrap(*args, **kwargs)
#      82 try:
#      83     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 84     return f(*args, **kwargs)
#      85 finally:
#      86     t2 = time.time_ns()
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/zoo_manager.py:319, in ZooManager.load_model(self, model_name, **kwargs)
#     257 @log_wrap
#     258 def load_model(self, model_name: str, **kwargs) -> Model:
#     259     """Create and return the model handling object for given model name.
#     260
#     261     Args:
#    (...)    317
#     318     """
# --> 319     model = self._zoo.load_model(model_name)
#     320     for key, value in kwargs.items():
#     321         if hasattr(Model, key):
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/log.py:84, in log_wrap.<locals>.wrap(*args, **kwargs)
#      82 try:
#      83     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 84     return f(*args, **kwargs)
#      85 finally:
#      86     t2 = time.time_ns()
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/_zoo_accessor.py:632, in _LocalHWCloudZooAccessor.load_model(self, model)
#     621 @log_wrap
#     622 def load_model(self, model: str):
#     623     """Create model object for given model name.
#     624
#     625     Args:
#    (...)    629         model object corresponding to given model name
#     630     """
# --> 632     assets = self._get_model_assets(model, True)
#     633     model_params: ModelParams = copy.deepcopy(assets.model_params)
#     634     model_params.CloudModelName = self.ext_model_name(model)
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/_zoo_accessor.py:583, in _CloudZooAccessorBase._get_model_assets(self, model, get_labels)
#     580 assets = self._assets.get(model)
#     582 if assets is None or assets.model_params is None:
# --> 583     model_info = self._cloud_server_request(
#     584         f"/zoo/v1/public/models{self._zoo_url}/{model}/info"
#     585     )
#     587     assets = self._Assets(
#     588         ModelParams(json.dumps(model_info["model_params"])),
#     589         Model._harmonize_label_dictionary(model_info["model_labels"]),
#     590     )
#     591     self._assets[model] = assets
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/log.py:84, in log_wrap.<locals>.wrap(*args, **kwargs)
#      82 try:
#      83     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 84     return f(*args, **kwargs)
#      85 finally:
#      86     t2 = time.time_ns()
#
# File ~/hailo_examples/degirum_env/lib/python3.11/site-packages/degirum/_zoo_accessor.py:501, in _CloudZooAccessorBase._cloud_server_request(self, api_url, is_octet_stream)
#     499     except json.JSONDecodeError:
#     500         pass
# --> 501     raise DegirumException(details) from None
#     503 # if we followed a redirect to https, update url
#     504 if (
#     505     len(res.history) == 1
#     506     and res.url.startswith("https://")
#     507     and self._url.startswith("http://")
#     508 ):
#
# DegirumException: could not get model by url. (cloud server response: 400 Client Error: Bad Request for url: https://hub.degirum.com/zoo/v1/public/models/degirum/hailo/yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1/info)

# %% [markdown]
# ### Listing Models
# You can explore the models available using `degirum.list_models()` method.

# %%
import degirum as dg, degirum_tools

inference_host_address = "@local"
zoo_url = 'degirum/hailo'
token=''
device_type=['HAILORT/HAILO8']

model_list=dg.list_models(
    inference_host_address=inference_host_address,
    zoo_url=zoo_url,
    token=token,
    device_type=device_type
)
for index, model_name in enumerate(model_list):
    print(index, model_name)

# %% [markdown]
# ### Switch to local model zoo
# In this repo, we provide a `models` folder with a couple of example models. You can use the code block as a reference to run models from a local folder.

# %%
import degirum as dg

inference_host_address = "@local"
zoo_url = '../models'
token=''
device_type='HAILORT/HAILO8'

model_list = dg.list_models(
    inference_host_address=inference_host_address,
    zoo_url=zoo_url,
    token=token,
    device_type=device_type 
)

for model_name in model_list.keys():
    print(model_name)

# %%
import degirum as dg, degirum_tools

inference_host_address = "@local"
zoo_url = '../models'
token=''
device_type='HAILORT/HAILO8'

# set model name, inference host address, zoo url, token, and image source
model_name = "yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1"
image_source='../assets/ThreePersons.jpg'

# load AI model
model = dg.load_model(
    model_name=model_name,
    inference_host_address=inference_host_address,
    zoo_url='../models',
    token=token,
    device_type=device_type
)

# perform AI model inference on given image source
print(f" Running inference using '{model_name}' on image source '{image_source}'")
inference_result = model(image_source)

# print('Inference Results \n', inference_result)  # numeric results
print(inference_result)
print("Press 'x' or 'q' to stop.")

# show results of inference
with degirum_tools.Display("AI Camera") as output_display:
    output_display.show_image(inference_result)
# Out:
#  Running inference using 'yolov8n_relu6_coco--640x640_quant_hailort_hailo8_1' on image source '../assets/ThreePersons.jpg'
# - bbox: [50.76686096191406, 11.557281494140625, 260.00616455078125, 422.2589111328125]
#   category_id: 0
#   label: person
#   score: 0.9210436940193176
# - bbox: [425.75750732421875, 20.109344482421875, 639.9440307617188, 353.2565612792969]
#   category_id: 0
#   label: person
#   score: 0.888812780380249
# - bbox: [204.74893188476562, 45.846923828125, 453.3245544433594, 401.99920654296875]
#   category_id: 0
#   label: person
#   score: 0.8193221092224121
#
# Press 'x' or 'q' to stop.
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/william/hailo_examples/degirum_env/lib/python3.11/site-packages/cv2/qt/plugins"
