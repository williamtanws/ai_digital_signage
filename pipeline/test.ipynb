# %%
# import degirum and degirum_tools
import degirum as dg, degirum_tools

inference_host_address = "@local"
zoo_url = 'degirum/hailo'
token=''
device_type='HAILORT/HAILO8'

print(dg.list_models(inference_host_address="@local"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 token=''
#       7 device_type='HAILORT/HAILO8'
# ----> 9 print(dg.list_models(inference_host_address="@local"))
#
# TypeError: list_models() missing 1 required positional argument: 'zoo_url'
